# %% [markdown]
# # Checking P/S Ratio

# %%
# Code based on Book: Build Your Own AI Investor
# Damon Lee 2020
# Check out the performance on www.valueinvestingai.com, ai-investor.net
# Code uses bulk download data from the (presumably) nice people at https://simfin.com/.

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import math

from platform import python_version
print(python_version())
# Out:
# 3.7.7

# %% [markdown]
# # 1. Get raw 'y' and 'x'
#
# Where x is a DataFrame of the fundamental stock information to get P/S
#
# And y is a DataFrame with data to get the stock return

# %%
# Get the daily share price data from SimFin.com bulk download
def getYRawData():
    d=pd.read_csv('us-shareprices-daily.csv', delimiter=';')
    d["Date"]=pd.to_datetime(d["Date"])
    print('Stock Price data matrix is: ',d.shape)
    return d

# Get the stock income statement data from SimFin.com bulk download
def getXData():
    a=pd.read_csv('us-income-annual.csv', delimiter=';')
    print('Income Statement CSV is: ', a.shape)
    a["Report Date"] = pd.to_datetime(a["Report Date"])
    a["Publish Date"] = pd.to_datetime(a["Publish Date"])
    return a


# Return just the price and volume near date (as have imperfect data).
# Want the volume data returned, to remove stocks with near 0 volume later.
# d is just the raw daily stock price data
# Modifier modifies the date to look between.
def getYPriceDataNearDate(ticker, date, modifier, d):
    windowDays=5
    rows = \
    d[(d["Date"].between(pd.to_datetime(date) + pd.Timedelta(days=modifier),\
       pd.to_datetime(date) + pd.Timedelta(days=windowDays+modifier))) \
      & (d["Ticker"]==ticker)]
    if rows.empty:
        return [ticker, np.float("NaN"),\
                np.datetime64('NaT'),\
                np.float("NaN")]
    else:
        return [ticker, rows.iloc[0]["Open"],\
                rows.iloc[0]["Date"],\
                rows.iloc[0]["Volume"]*rows.iloc[0]["Open"]]
        #take the first item of the list of days that fall in the window of accepted days.
        

        
# Modifier is effectively the hold period for a stock (here it is 1 year)
# x is the vector of company data
# d is the raw daily stock price data data (stock price and date for all days)
def getYPricesReportDateAndTargetDate(x, d, modifier=365):
    i=0
    # Preallocation list of list of 2 \
    # [(price at date) (price at date + modifier)]
    y = [[None]*8 for i in range(len(x))] 
    
    whichDateCol='Publish Date' # is the performance date from->to. Want this to be publish date.
    
    # Because of time lag between report date\
    # (which can't be actioned on) and publish date\
    # (data we can trade with)
    for index in range(len(x)):
        y[i]=(getYPriceDataNearDate(\
            x['Ticker'].iloc[index], x[whichDateCol].iloc[index], 0, d) + \
              getYPriceDataNearDate(\
            x['Ticker'].iloc[index], x[whichDateCol].iloc[index], modifier, d))
        i=i+1
    return y

# %%
x = getXData()
# Out:
# Income Statement CSV is:  (17771, 28)

# %%
# See the daily stock data
d = getYRawData()
d[d['Ticker']=='GOOG']
# Out:
# Stock Price data matrix is:  (5884948, 11)
#      Ticker  SimFinId       Date     Open      Low     High    Close  \
# 0      GOOG        18 2014-03-27   568.00   552.92   568.00   558.46
# 1      GOOG        18 2014-03-28   561.20   558.67   566.43   559.99
# 2      GOOG        18 2014-03-31   566.89   556.93   567.00   556.97
# 3      GOOG        18 2014-04-01   558.71   558.71   568.45   567.16
# 4      GOOG        18 2014-04-02   565.11   562.19   604.83   567.00
# ...     ...       ...        ...      ...      ...      ...      ...
# 1606   GOOG        18 2020-08-12  1485.58  1485.25  1512.39  1506.62
# 1607   GOOG        18 2020-08-13  1510.34  1508.01  1537.25  1518.45
# 1608   GOOG        18 2020-08-14  1515.66  1502.88  1521.90  1507.73
# 1609   GOOG        18 2020-08-17  1514.67  1507.97  1525.61  1517.98
# 1610   GOOG        18 2020-08-18  1526.18  1523.71  1562.47  1558.60
#
#       Adj. Close  Dividend   Volume  Shares Outstanding
# 0         558.46       NaN    13100         336050831.0
# 1         559.99       NaN    41100         336050831.0
# 2         556.97       NaN    10800         674462000.0
# 3         567.16       NaN     7900         674462000.0
# 4         567.00       NaN   146700         674462000.0
# ...          ...       ...      ...                 ...
# 1606     1506.62       NaN  1437655         680163635.0
# 1607     1518.45       NaN  1455208         680163635.0
# 1608     1507.73       NaN  1355200         680163635.0
# 1609     1517.98       NaN  1364082         680163635.0
# 1610     1558.60       NaN  2024058         680163635.0
#
# [1611 rows x 11 columns]

# %%
# We want to know the performance for each stock, each year, between 10-K report dates.
# takes VERY long time, several hours.
y = getYPricesReportDateAndTargetDate(x, d, 365) # because of lookups in this function.

# %%
y= pd.DataFrame(y, columns=['Ticker', 'Open Price', 'Date', 'Volume', 'Ticker2', 'Open Price2', 'Date2', 'Volume2'])

y.to_csv("Annual_Stock_Price_Performance_.csv")
x.to_csv("Annual_Stock_Price_Fundamentals_.csv")

# %%
# Find out things about Y data
print("Y Shape:", y.shape)
print("X Shape:", x.shape)
# Out:
# Y Shape: (17771, 8)
# X Shape: (17771, 28)

# %% [markdown]
# # 2. Filter down the data
# Due to imperfect data and some stocks have low volume

# %%
x=pd.read_csv("Annual_Stock_Price_Fundamentals_.csv", index_col=0)
y=pd.read_csv("Annual_Stock_Price_Performance_.csv", index_col=0)

# %%
# Issue where no share price
bool_list = ~y["Open Price"].isnull()
y=y[bool_list]
x=x[bool_list]

# Issues where no listed number of shares
bool_list = ~x["Shares (Diluted)"].isnull()
y=y[bool_list]
x=x[bool_list]

# Issue where there is low/no volume
bool_list =   ~((y['Volume']<1e4) | (y['Volume2']<1e4))
y=y[bool_list]
x=x[bool_list]

# Issue where dates missing (Removes latest data too, which we can't use)
bool_list = ~y["Date2"].isnull()
y=y[bool_list]
x=x[bool_list]
               
y=y.reset_index(drop=True)
x=x.reset_index(drop=True)

# %%
# Create Market Cap Column
x["Market Cap"] = y["Open Price"]*x["Shares (Diluted)"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (13866, 29)
# (13866, 8)

# %%
y
# Out:
#       Ticker  Open Price        Date        Volume Ticker2  Open Price2  \
# 0          A       16.12  2009-01-05  8.269076e+07       A        31.21
# 1          A       29.60  2009-12-21  9.319856e+07       A        40.65
# 2          A       37.59  2010-12-08  1.262986e+08       A        36.23
# 3          A       33.73  2011-12-16  1.053320e+08       A        39.98
# 4          A       40.58  2012-12-20  1.545570e+08       A        57.47
# ...      ...         ...         ...           ...     ...          ...
# 13861    low       74.51  2015-03-31  3.366399e+08     low        75.89
# 13862    low       75.04  2016-03-29  3.317825e+08     low        82.26
# 13863    low       81.91  2017-04-04  4.091163e+08     low        84.32
# 13864    low       87.35  2018-04-02  8.395805e+08     low       108.90
# 13865    low      104.76  2019-03-25  4.185011e+08     low        65.22
#
#             Date2       Volume2
# 0      2010-01-05  9.345210e+07
# 1      2010-12-21  1.469619e+08
# 2      2011-12-08  1.566078e+08
# 3      2012-12-17  1.381149e+08
# 4      2013-12-20  1.697664e+08
# ...           ...           ...
# 13861  2016-03-30  2.405867e+08
# 13862  2017-03-29  3.264436e+08
# 13863  2018-04-04  6.628260e+08
# 13864  2019-04-02  4.053657e+08
# 13865  2020-03-23  6.254391e+08
#
# [13866 rows x 8 columns]

# %%
x
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2008            FY  2008-10-31
# 1          A     45846      USD         2009            FY  2009-10-31
# 2          A     45846      USD         2010            FY  2010-10-31
# 3          A     45846      USD         2011            FY  2011-10-31
# 4          A     45846      USD         2012            FY  2012-10-31
# ...      ...       ...      ...          ...           ...         ...
# 13861    low    186050      USD         2014            FY  2015-02-28
# 13862    low    186050      USD         2015            FY  2016-02-29
# 13863    low    186050      USD         2016            FY  2017-02-28
# 13864    low    186050      USD         2017            FY  2018-02-28
# 13865    low    186050      USD         2018            FY  2019-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2009-01-05    2010-12-20     363000000.0       371000000.0  ...
# 1       2009-12-21    2011-12-16     346000000.0       346000000.0  ...
# 2       2010-12-08    2012-12-20     347000000.0       353000000.0  ...
# 3       2011-12-16    2013-12-19     347000000.0       355000000.0  ...
# 4       2012-12-20    2014-12-22     348000000.0       353000000.0  ...
# ...            ...           ...             ...               ...  ...
# 13861   2015-03-31    2017-04-04     988000000.0       990000000.0  ...
# 13862   2016-03-29    2017-04-04     927000000.0       929000000.0  ...
# 13863   2017-04-04    2017-04-04     880000000.0       881000000.0  ...
# 13864   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
# 13865   2019-03-23    2020-03-23     811000000.0       812000000.0  ...
#
#        Interest Expense, Net  Pretax Income (Loss), Adj.  \
# 0                -10000000.0                   815000000
# 1                -59000000.0                     7000000
# 2                -76000000.0                   560000000
# 3                -72000000.0                  1032000000
# 4                -92000000.0                  1043000000
# ...                      ...                         ...
# 13861           -516000000.0                  4276000000
# 13862           -552000000.0                  4419000000
# 13863           -645000000.0                  5201000000
# 13864           -633000000.0                  5953000000
# 13865           -624000000.0                  3394000000
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                          0.0             815000000
# 1                          0.0               7000000
# 2                  132000000.0             692000000
# 3                          NaN            1032000000
# 4                          NaN            1043000000
# ...                        ...                   ...
# 13861                      NaN            4276000000
# 13862                      NaN            4419000000
# 13863                      NaN            5201000000
# 13864             -464000000.0            5489000000
# 13865                      0.0            3394000000
#
#        Income Tax (Expense) Benefit, Net  \
# 0                          -1.220000e+08
# 1                          -3.800000e+07
# 2                          -8.000000e+06
# 3                          -2.000000e+07
# 4                           1.100000e+08
# ...                                  ...
# 13861                      -1.578000e+09
# 13862                      -1.873000e+09
# 13863                      -2.108000e+09
# 13864                      -2.042000e+09
# 13865                      -1.080000e+09
#
#        Income (Loss) from Continuing Operations  \
# 0                                     693000000
# 1                                     -31000000
# 2                                     684000000
# 3                                    1012000000
# 4                                    1153000000
# ...                                         ...
# 13861                                2698000000
# 13862                                2546000000
# 13863                                3093000000
# 13864                                3447000000
# 13865                                2314000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)  \
# 0                                   NaN   693000000            693000000
# 1                                   NaN   -31000000            -31000000
# 2                                   NaN   684000000            684000000
# 3                                   NaN  1012000000           1012000000
# 4                                   NaN  1153000000           1153000000
# ...                                 ...         ...                  ...
# 13861                               NaN  2698000000           2698000000
# 13862                               NaN  2546000000           2546000000
# 13863                               NaN  3093000000           3093000000
# 13864                               NaN  3447000000           3447000000
# 13865                               NaN  2314000000           2314000000
#
#          Market Cap
# 0      5.980520e+09
# 1      1.024160e+10
# 2      1.326927e+10
# 3      1.197415e+10
# 4      1.432474e+10
# ...             ...
# 13861  7.376490e+10
# 13862  6.971216e+10
# 13863  7.216271e+10
# 13864  7.337400e+10
# 13865  8.506512e+10
#
# [13866 rows x 29 columns]

# %%
x.to_csv("Annual_Stock_Price_Fundamentals_Filtered_.csv")
y.to_csv("Annual_Stock_Price_Performance_Filtered_.csv")

# %% [markdown]
# # 3. Create the P/S column

# %%
x=pd.read_csv("Annual_Stock_Price_Fundamentals_Filtered_.csv", index_col=0)
y=pd.read_csv("Annual_Stock_Price_Performance_Filtered_.csv", index_col=0)

# %%
def fixNansInX():
    x.loc[x["Revenue"].isnull(), "Revenue"]=0
            
def maxMinRatio(m, text, max, min):
    m.loc[x[text]>max,text]=max
    m.loc[x[text]<min,text]=min
            
def getYPerf(y):
    y_perf=pd.DataFrame()
    y_perf["Ticker"] = y["Ticker"]
    y_perf["Perf"]=(y["Open Price2"]-y["Open Price"])/y["Open Price"]
    y_perf[y_perf["Perf"].isnull()]=0 #y.fillna(0)
    return y_perf

# %%
fixNansInX()
x["P/S"] = x["Market Cap"] / x["Revenue"] 
maxMinRatio(x, "P/S", 1e5, 0) # Remove Infinities

y_perf = getYPerf(y)

# %% [markdown]
# # 4. Low P/S Backtest

# %%
def getBestStocksForYear(year, x): # Fiscal Year
    return x[x['Fiscal Year']==year].nlargest(20, 'P/S').index

# %%
ann_returns=[]
indx_rtn, indx_rtns=1, []

for yr in range(2008,2019):
    indx = getBestStocksForYear(yr, x)
    #print(x.loc[indx]['Publish Date'])
    port_return = y_perf.loc[indx]['Perf'].mean()
    print('Portfolio Return was: ', round(port_return,2), 'for Fiscal Year: ',yr)
    indx_rtn = indx_rtn*(1+port_return)
    indx_rtns.append(indx_rtn) 
    ann_returns.append(port_return)
    for row in y_perf.loc[indx].iterrows():
        print(row[1]['Ticker'], 'Return: ', round(row[1]['Perf'],2))
    print('------------------------------------------------------')
# Out:
# Portfolio Return was:  0.38 for Fiscal Year:  2008
# LH Return:  0.17
# V Return:  0.52
# CELG Return:  0.07
# FSLR Return:  -0.2
# GILD Return:  -0.1
# AMT Return:  0.37
# LUK Return:  0.55
# VRSN Return:  0.21
# PSA Return:  0.18
# QCOM Return:  0.11
# BLK Return:  -0.03
# HCP Return:  0.19
# AVB Return:  0.47
# VTR Return:  0.46
# ISRG Return:  2.2
# AKAM Return:  0.45
# CME Return:  0.6
# AMGN Return:  0.01
# CCI Return:  0.74
# RRC Return:  0.59
# ------------------------------------------------------
# Portfolio Return was:  0.3 for Fiscal Year:  2009
# LH Return:  0.28
# ODFL Return:  0.65
# ZIOP Return:  0.41
# CTIC Return:  -0.66
# VRTX Return:  0.02
# V Return:  0.03
# Joe Return:  0.07
# NSH Return:  0.38
# LSI_old Return:  0.18
# ISRG Return:  -0.08
# ALXN Return:  0.78
# CLR Return:  0.65
# CELG Return:  -0.09
# AMT Return:  0.26
# PXD Return:  0.11
# LUK Return:  0.43
# RRC Return:  0.06
# CAVM Return:  0.71
# MELI Return:  0.89
# VMW Return:  0.85
# ------------------------------------------------------
# Portfolio Return was:  -0.2 for Fiscal Year:  2010
# ACRX Return:  -0.32
# ARWR Return:  -0.38
# AVXL Return:  -0.61
# CIE Return:  0.53
# CORT Return:  -0.15
# ECYT Return:  -0.5
# INFI Return:  0.13
# LH Return:  -0.04
# MTEM Return:  0.27
# ODFL Return:  0.46
# ZIOP Return:  -0.09
# MNKD Return:  -0.57
# CTIC Return:  -0.52
# NVAX Return:  -0.34
# GERN Return:  -0.59
# LXRX Return:  -0.14
# PACB Return:  -0.72
# CYCC Return:  -0.5
# INVA Return:  -0.21
# ASCMA Return:  0.29
# ------------------------------------------------------
# Portfolio Return was:  1.95 for Fiscal Year:  2011
# AVXL Return:  -0.39
# CIE Return:  0.19
# CLRB Return:  0.56
# CORT Return:  -0.36
# CTIC Return:  -0.74
# CYCC Return:  0.12
# INFI Return:  4.35
# LH Return:  0.01
# MEIP Return:  -0.69
# ODFL Return:  0.22
# PSTI Return:  0.46
# TGTX Return:  30.6
# VSTM Return:  -0.09
# ZIOP Return:  -0.29
# MNKD Return:  0.11
# MTEM Return:  2.46
# ECYT Return:  1.59
# RAVE Return:  -0.08
# LXRX Return:  0.35
# TROV Return:  0.53
# ------------------------------------------------------
# Portfolio Return was:  0.63 for Fiscal Year:  2012
# AVXL Return:  -0.46
# CIE Return:  -0.23
# CLRB Return:  -0.15
# CTIC Return:  2.0
# GTXI Return:  -0.63
# INFI Return:  -0.68
# MEIP Return:  3.1
# ODFL Return:  0.48
# PBYI Return:  2.09
# RGLS Return:  0.66
# STML Return:  1.44
# TSRO Return:  0.96
# VSTM Return:  0.2
# WNDW Return:  2.21
# ZIOP Return:  -0.21
# MNKD Return:  1.06
# TGTX Return:  0.16
# LXRX Return:  -0.15
# CYCC Return:  -0.34
# RAVE Return:  1.04
# ------------------------------------------------------
# Portfolio Return was:  0.1 for Fiscal Year:  2013
# AVXL Return:  -0.61
# CIE Return:  -0.5
# EGLT Return:  -0.11
# GLYC Return:  -0.2
# GTXI Return:  -0.56
# INFI Return:  0.04
# KPTI Return:  -0.16
# MEIP Return:  -0.23
# MNKD Return:  0.26
# ODFL Return:  0.48
# OPHT Return:  0.68
# PBYI Return:  0.91
# RGLS Return:  0.61
# STML Return:  -0.23
# TSRO Return:  0.28
# VSTM Return:  -0.44
# ZIOP Return:  1.9
# PTN Return:  0.23
# IMMY Return:  0.16
# ICPT Return:  -0.4
# ------------------------------------------------------
# Portfolio Return was:  -0.2 for Fiscal Year:  2014
# AVXL Return:  4.69
# CALA Return:  -0.75
# CCXI Return:  -0.58
# CIE Return:  -0.7
# CLRB Return:  -0.81
# CQH Return:  -0.37
# GLYC Return:  -0.35
# GTXI Return:  -0.17
# HGEN Return:  -0.32
# INFI Return:  -0.63
# KITE Return:  -0.28
# KPTI Return:  -0.72
# MEIP Return:  -0.74
# MNKD Return:  -0.88
# NBIX Return:  -0.04
# NERV Return:  0.07
# ODFL Return:  -0.18
# PBYI Return:  -0.79
# PTN Return:  -0.03
# RGLS Return:  -0.53
# ------------------------------------------------------
# Portfolio Return was:  0.24 for Fiscal Year:  2015
# AGR Return:  -0.04
# ALPN Return:  -0.52
# AVXL Return:  -0.28
# AXON Return:  0.73
# BPMC Return:  1.37
# CALA Return:  1.04
# CCXI Return:  0.94
# CIE Return:  -0.62
# CLRB Return:  -0.46
# CQH Return:  0.71
# FOLD Return:  0.03
# GBT Return:  0.47
# GLYC Return:  0.33
# GTXI Return:  -0.13
# INFI Return:  -0.6
# KPTI Return:  0.21
# KURA Return:  1.04
# MEIP Return:  -0.03
# MNKD Return:  -0.39
# NERV Return:  1.0
# ------------------------------------------------------
# Portfolio Return was:  0.63 for Fiscal Year:  2016
# AGR Return:  0.14
# ALPN Return:  0.04
# AXON Return:  -0.82
# BPMC Return:  1.85
# CALA Return:  -0.3
# CASI Return:  2.09
# CLRB Return:  -0.54
# CQH Return:  0.15
# CRVS Return:  -0.4
# GBT Return:  0.47
# GLYC Return:  2.69
# GTXI Return:  2.93
# INFI Return:  -0.14
# KPTI Return:  0.64
# KURA Return:  1.42
# MEIP Return:  0.61
# NERV Return:  -0.31
# ODFL Return:  0.54
# OLED Return:  0.85
# PBYI Return:  0.74
# ------------------------------------------------------
# Portfolio Return was:  -0.31 for Fiscal Year:  2017
# AGR Return:  0.01
# ALPN Return:  -0.22
# ALRN Return:  -0.79
# ARQL Return:  1.02
# AXON Return:  -0.9
# BPMC Return:  -0.06
# CASI Return:  -0.17
# CLRB Return:  -0.79
# CRVS Return:  -0.4
# CYCC Return:  -0.31
# DCPH Return:  0.04
# EVFM Return:  -0.49
# GBT Return:  -0.15
# GLYC Return:  -0.35
# GTHX Return:  -0.13
# GTXI Return:  -0.94
# INFI Return:  -0.3
# KPTI Return:  -0.67
# KURA Return:  -0.34
# MBOT Return:  -0.24
# ------------------------------------------------------
# Portfolio Return was:  -0.1 for Fiscal Year:  2018
# ADIL Return:  -0.66
# AGR Return:  0.03
# ALPN Return:  -0.63
# ALRN Return:  -0.81
# AXON Return:  -0.11
# BPMC Return:  -0.21
# BTAI Return:  2.02
# CASI Return:  -0.34
# CHRS Return:  0.3
# CLBS Return:  -0.48
# CLRB Return:  0.26
# CRVS Return:  -0.17
# DCPH Return:  0.59
# EVFM Return:  0.52
# EVLO Return:  -0.49
# GBT Return:  0.17
# GLYC Return:  -0.71
# GTHX Return:  -0.09
# GTXI Return:  -0.67
# INFI Return:  -0.48
# ------------------------------------------------------

# %%
plt.plot(range(2009,2020),indx_rtns,'x--')
plt.grid()
plt.ylabel('Indexed Return')
plt.xlabel('Year')
plt.title('Low P/S Strategy - Annual Portfolio Performance',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Low P/S Strategy - Annual Portfolio Performance')

# %%
# Return
indx_rtn
# Out:
# 7.620536161803234

# %% [markdown]
# ## Issues:
# * No accounting for bankruptcy
# * No accounting for mergers etc.
